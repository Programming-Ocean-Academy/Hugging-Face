# %% [markdown]
# ---
#
# # Top 100 Most-Used Models on Hugging Face
#
# ### The definitive popularity list — across LLMs, embeddings, vision, diffusion, audio, and multimodal models.
#
# ---
#
# # A. Large Language Models (LLMs) — 30 Models
#
# ### These dominate HF usage: chatbots, RAG, agents, assistants, and enterprise AI.
#
# 1. meta-llama/Llama-3-70B-Instruct
# 2. meta-llama/Llama-3-8B-Instruct
# 3. meta-llama/Llama-2-70B-chat
# 4. meta-llama/Llama-2-13B-chat
# 5. meta-llama/Llama-2-7B-chat
# 6. mistralai/Mixtral-8x7B-Instruct
# 7. mistralai/Mistral-7B-Instruct-v0.3
# 8. mistralai/Mistral-Nemo-12B-Instruct
# 9. google/gemma-2b-it
# 10. google/gemma-7b-it
# 11. Qwen/Qwen2-72B-Instruct
# 12. Qwen/Qwen2-7B-Instruct
# 13. Qwen/Qwen1.5-14B-Chat
# 14. Qwen/Qwen1.5-7B-Chat
# 15. microsoft/Phi-3-mini-4k-instruct
# 16. microsoft/Phi-3-small-8k-instruct
# 17. HuggingFaceH4/zephyr-7b-beta
# 18. NousResearch/Hermes-2-Pro-Llama-3-8B
# 19. mistralai/Mistral-7B-v0.1
# 20. tiiuae/Falcon-180B-chat
# 21. tiiuae/Falcon-7B-instruct
# 22. EleutherAI/gpt-neox-20b
# 23. EleutherAI/gpt-j-6b
# 24. bigscience/bloomz-7b1
# 25. bigscience/bloom-560m
# 26. bigcode/starcoder2-7b
# 27. bigcode/starcoder2-3b
# 28. Salesforce/codegen-6B-mono
# 29. databricks/dbrx-instruct
# 30. openchat/openchat-3.6-8b
#
# ---
#
# # B. Embedding & Retrieval Models — 15 Models
#
# ### Essential for RAG, vector search, enterprise retrieval.
#
# 31. sentence-transformers/all-MiniLM-L6-v2
# 32. sentence-transformers/all-MiniLM-L12-v2
# 33. sentence-transformers/multi-qa-MiniLM-L6-cos-v1
# 34. sentence-transformers/all-mpnet-base-v2
# 35. sentence-transformers/e5-large-v2
# 36. intfloat/e5-mistral-7b-instruct
# 37. nomic-ai/nomic-embed-text-v1
# 38. jinaai/jina-embeddings-v2-base-en
# 39. Alibaba-NLP/gte-large
# 40. BAAI/bge-large-en-v1.5
# 41. BAAI/bge-base-en-v1.5
# 42. BAAI/bge-m3
# 43. facebook/dpr-question_encoder
# 44. facebook/dpr-context_encoder
# 45. voyageai/voyage-2-lite (open variants)
#
# ---
#
# # C. Computer Vision Models — 15 Models
#
# ### Detectors, classifiers, segmentors — widely used in CV pipelines.
#
# 46. facebook/dino-v2-giant
# 47. facebook/dinov2-base
# 48. google/vit-base-patch16-224
# 49. microsoft/resnet-50
# 50. apple/mobilevit-xxs
# 51. facebook/deit-base-distilled-patch16-224
# 52. facebook/convnext-base-224
# 53. ultralytics/yolov8n
# 54. ultralytics/yolov8s
# 55. ultralytics/yolov8m
# 56. ultralytics/yolov5s
# 57. ultralytics/yolov7
# 58. facebook/sam-vit-h (Segment Anything)
# 59. facebook/mask2former-swin-large-coco
# 60. facebook/detr-resnet-50
#
# ---
#
# # D. Image Generation & Diffusion Models — 15 Models
#
# ### The most downloaded models in the Diffusers ecosystem.
#
# 61. stabilityai/stable-diffusion-xl-base-1.0
# 62. stabilityai/stable-diffusion-xl-refiner-1.0
# 63. runwayml/stable-diffusion-v1-5
# 64. stabilityai/stable-diffusion-2-1
# 65. stabilityai/stable-diffusion-2-depth
# 66. black-forest-labs/FLUX.1-canny-dev
# 67. stabilityai/stable-cascade
# 68. byteDance/AnimateDiff
# 69. TencentARC/ControlNet-canny
# 70. TencentARC/ControlNet-depth
# 71. deepfloyd/IF-I-XL-v1.0
# 72. deepfloyd/IF-II-L-v1.0
# 73. kandinsky-community/kandinsky-2-2-decoder
# 74. CompVis/ldm-text2im-large-256
# 75. stabilityai/sdxl-turbo
#
# ---
#
# # E. Audio, Speech & Voice Models — 10 Models
#
# ### ASR, TTS, classification — extremely high HF usage.
#
# 76. openai/whisper-large-v3
# 77. openai/whisper-small
# 78. facebook/wav2vec2-base-960h
# 79. facebook/hubert-large-ls960-ft
# 80. microsoft/xtts-v2
# 81. coqui/XTTS-v1
# 82. speechbrain/asr-transformer-transformerlm-librispeech
# 83. speechbrain/tts-tacotron2-ljspeech
# 84. microsoft/speecht5_tts
# 85. microsoft/speecht5_vc
#
# ---
#
# # F. Video Generation, Motion, and Animation Models — 5 Models
#
# 86. stabilityai/stable-video-diffusion-img2vid
# 87. stabilityai/stable-video-diffusion-text2vid
# 88. tencentarc/animatediff-motion-adapter
# 89. OpenSora/OpenSora-1.1
# 90. pixart-alpha/pixart-sigma
#
# ---
#
# # G. Multimodal Models — 10 Models
#
# ### Vision + Language models, retrieval, captioning, VQA.
#
# 91. openai/clip-vit-base-patch32
# 92. openai/clip-vit-large-patch14
# 93. laion/CLIP-ViT-B-32-laion2B
# 94. Salesforce/blip2-flan-t5-xl
# 95. Salesforce/blip2-opt-2.7b
# 96. microsoft/kosmos-2
# 97. llava-hf/llava-1.6-mistral-7b
# 98. llava-hf/llava-1.5-7b
# 99. internvl/internvl-chat-v1-5
# 100. imagebind/imagebind-huge
