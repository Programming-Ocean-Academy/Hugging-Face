# %% [markdown]
# # Models → Datasets → Spaces → Libraries → Workflows → Tools → Infrastructure
# ```
#                                  ┌──────────────────────────┐
#                                  │      HUGGING FACE HUB    │
#                                  │   (Unified AI Ecosystem) │
#                                  └──────────────┬───────────┘
#                                                 │
#         ┌────────────────────────────────────────┼────────────────────────────────────────┐
#         │                                        │                                        │
# ┌───────────────┐                        ┌───────────────┐                        ┌────────────────┐
# │   MODELS       │                        │   DATASETS    │                        │    SPACES      │
# │ (1M+ models)   │                        │ (300k+ sets)  │                        │  (300k+ apps)  │
# └───────┬────────┘                        └──────┬────────┘                        └──────┬─────────┘
#         │                                        │                                        │
#         │                                        │                                        │
#         ▼                                        ▼                                        ▼
#  ┌──────────────┐                        ┌────────────────┐                        ┌──────────────────┐
#  │  LLMs         │                        │   NLP corpora  │                        │   GRADIO Apps    │
#  │  (Chat, RAG)  │                        │   Vision sets   │                        │   STREAMLIT Apps │
#  ├──────────────┤                        │   Audio sets    │                        │   Static Sites   │
#  │  Embeddings   │                        │   RL datasets   │                        │   Docker Apps    │
#  │  (Search/RAG) │                        │   Synthetic     │                        └──────────────────┘
#  ├──────────────┤                        │   Benchmarks    │
#  │  Vision       │                        └────────────────┘
#  │  (YOLO, SAM)  │
#  ├──────────────┤
#  │ Diffusion     │
#  │ (SDXL, IF)    │
#  ├──────────────┤
#  │ Audio/Voice   │
#  │ (Whisper/TTS) │
#  └──────────────┘
#
# ```

# %% [markdown]
# # The engines powering the entire ecosystem
# ```
#                        ┌────────────────────────────────────────────┐
#                        │              HF LIBRARIES                   │
#                        └───────────────┬────────────────────────────┘
#                                        │
#         ┌──────────────────────────────┼────────────────────────────┐
#         │                              │                            │
# ┌──────────────┐             ┌─────────────────┐         ┌───────────────────────┐
# │ Transformers │             │   Diffusers     │         │     Tokenizers         │
# │ (NLP/LLMs)   │             │ (SD, Video Gen) │         │ (Fast Rust/BPE/SentencePiece)
# └──────┬───────┘             └───────┬────────┘         └──────────┬────────────┘
#        │                               │                           │
#        ▼                               ▼                           ▼
# ┌─────────────┐              ┌────────────────┐           ┌───────────────────────┐
# │ PEFT / LoRA │              │ ControlNet      │           │ fast tokenizer builds │
# │ (finetuning)│              │ Schedulers      │           │ vocab files           │
# └─────────────┘              └────────────────┘           └───────────────────────┘
#
# ```

# %% [markdown]
# # How developers combine everything on the Hub
#
# ```
#                       ┌────────────────────────────────────────────┐
#                       │                WORKFLOWS                    │
#                       └───────────────┬────────────────────────────┘
#                                       │
#              ┌────────────────────────┼──────────────────────────────┐
#              │                        │                              │
#      ┌──────────────┐        ┌────────────────┐            ┌────────────────────┐
#      │ Inference     │        │ Fine-tuning    │            │ RAG Pipelines      │
#      │ (HF Inference │        │ (PEFT/LoRA)    │            │ (LLM+Embeddings+DB)│
#      │  API / TGI)   │        └────────────────┘            └────────────────────┘
#      └───────┬──────┘               │                               │
#              │                      ▼                               ▼
#              ▼              ┌────────────────┐            ┌────────────────────────┐
#      ┌──────────────┐       │ Training Loops │            │ Vector Databases       │
#      │ Accelerate    │       │ (Accelerate)   │            │ (FAISS, Weaviate, etc)│
#      └──────────────┘       └────────────────┘            └────────────────────────┘
# ```

# %% [markdown]
# # How Hugging Face serves billions of requests
#
# ```
#                           ┌─────────────────────────────────────┐
#                           │         INFRASTRUCTURE               │
#                           └──────────────────────┬──────────────┘
#                                                 │
#                     ┌───────────────────────────┼───────────────────────────┐
#                     │                           │                           │
#           ┌────────────────┐        ┌────────────────────────┐   ┌───────────────────┐
#           │ HuggingFace Hub│        │ Inference Endpoints     │   │  Text Generation  │
#           │ (Versioning,    │        │ (Serverless/Hosted TGI)│   │  Inference (TGI)  │
#           │ repos, APIs)    │        └────────────────────────┘   └───────────────────┘
#           └────────────────┘
#                     │
#                     ▼
#          ┌────────────────────────┐
#          │   Model Cards / Docs    │
#          │  (Metadata, training,   │
#          │   eval, citations)      │
#          └────────────────────────┘
# ```

# %% [markdown]
# # High-Level Knowledge Graph (Condensed Mind Map)
#
# ```
# HUGGING FACE
# │
# ├── MODELS
# │   ├── LLMs
# │   ├── Embeddings
# │   ├── Vision (YOLO, SAM, DETR)
# │   ├── Diffusion (SDXL, IF)
# │   ├── Audio (Whisper, TTS)
# │   └── Multimodal (CLIP, LLaVA)
# │
# ├── DATASETS
# │   ├── NLP
# │   ├── CV
# │   ├── Audio
# │   ├── Multimodal
# │   └── Benchmarks
# │
# ├── SPACES
# │   ├── Gradio
# │   ├── Streamlit
# │   ├── Docker
# │   └── Static sites
# │
# ├── LIBRARIES
# │   ├── Transformers
# │   ├── Diffusers
# │   ├── Tokenizers
# │   ├── Accelerate
# │   ├── PEFT
# │   └── Evaluate / Datasets
# │
# ├── WORKFLOWS
# │   ├── Inference (TGI)
# │   ├── Finetuning (PEFT)
# │   ├── RAG Pipelines
# │   ├── Vector Search
# │   └── Deployment
# │
# └── INFRASTRUCTURE
#     ├── Hub
#     ├── Endpoints
#     ├── Model Cards
#     └── Version Control
# ```
