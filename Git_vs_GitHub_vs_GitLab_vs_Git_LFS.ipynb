# %% [markdown]
# ![images.webp](data:image/webp;base64,...)

# %% [markdown]
# # Git vs GitHub vs GitLab vs Git LFS — Full Comprehensive Comparison Table
#
# | Dimension | Git | GitHub | GitLab | Git LFS |
# |----------|------|---------|---------|----------|
# | Category | Version control tool | Cloud platform built on Git | Cloud and self-hosted platform built on Git | Git extension for large file handling |
# | Creator | Linus Torvalds (2005) | Tom Preston-Werner and GitHub team (2008) | GitLab Inc. (2011) | GitHub (2015) |
# | Primary Purpose | Track code changes, branches, merge history | Host Git repositories with collaboration and community features | Host Git repositories with full DevOps lifecycle | Store big files in Git without performance issues |
# | Type | Command-line system | SaaS and cloud hosting service | SaaS and self-hosted DevOps platform | Extension to Git |
# | Where It Runs | Local machine | Cloud (GitHub.com), GitHub Enterprise | Cloud or self-hosted (GitLab CE/EE) | Integrated inside Git repositories |
# | Main Use Case | Version control | Code hosting, collaboration, open-source workflows | CI/CD, DevOps automation, self-hosting | Store large files such as models, datasets, binaries |
# | Core Concepts | Commits, branches, tags, merges | Issues, pull requests, forks, actions | Issues, merge requests, pipelines | Pointers to large files stored outside Git |
# | Stores Code? | Yes (locally only) | Yes (cloud) | Yes (cloud and on-prem) | Stores pointers, not actual files |
# | Tracks Large Files? | No | Limited; requires LFS | Limited; supports LFS | Yes (specialized for this) |
# | Best For | Developers writing code | Public open-source, collaboration, social coding | Enterprise DevOps, CI/CD automation | ML models, datasets, images, binaries |
# | Social Features | None | Stars, forks, followers, trending repositories | Less social, more enterprise-focused | None |
# | Pull vs Merge Requests | Not applicable | Pull Requests | Merge Requests | Not applicable |
# | CI/CD Support | None | GitHub Actions | GitLab CI/CD (industry-leading) | None |
# | Project Management | None | Issues, Projects | Issues, Epics, Boards, Roadmaps | None |
# | Runner / Pipeline Execution | Not applicable | GitHub Actions Runners | GitLab Runners (self-hosted or cloud) | Not applicable |
# | User Base | Developers worldwide | Largest developer community (100M+) | Enterprise teams and developers | Git users handling large files |
# | Open Source? | Open-source | Mostly closed-source with limited open-source parts | Open-source Community Edition plus Enterprise Edition | Open-source |
# | Self-hosted Option | Yes (Git installed locally) | GitHub Enterprise Server (paid) | Yes (GitLab CE is free) | Integrated with any Git server |
# | Authentication | None (local use) | OAuth, personal access tokens, SSO | OAuth, PATs, LDAP, SAML, SSO | Uses Git credentials |
# | Monetization | Free tool | Free, Pro, Team, Enterprise | Free CE, Premium, Ultimate | Free extension |
# | Security Tools | None | Secret scanning, Dependabot, code scanning | Static analysis, secret detection, compliance frameworks | None |
# | DevOps Coverage | None | Partial (CI/CD and packages) | Full lifecycle: Plan → Create → Verify → Package → Release → Monitor → Secure | None |
# | Package Registry | None | GitHub Packages | GitLab Package Registry | None |
# | Wiki / Docs | None | Repository Wikis and Pages | Repository Wikis and Pages | None |
# | Pipelines for ML | Not built-in | GitHub Actions supports ML training workflows | GitLab CI ideal for automated ML pipelines | Used for storing ML model weights |
# | Scaling | Extremely scalable on distributed clients | Highly scalable cloud infrastructure | Highly scalable and supports on-prem scaling | Scales large file storage |
# | Governance | Maintained by Linux Foundation | Owned by Microsoft | Independent company | Maintained by GitHub |
# | File Storage Behavior | Stores entire file for each commit | Stores diffs at Git level | Stores diffs at Git level | Stores pointer files; content stored separately |
# | Large Files Problem | Git repository becomes huge and slow | Same Git limitation | Same Git limitation | Solves the Git limitation for large binary files |
# | User Interface | CLI only | Web UI and Desktop App | Web UI | No UI |
# | Learning Curve | High (CLI tools) | Easy due to UI | Moderate because of extensive features | Low (light extension) |
# | Ideal For ML Engineers | No | Hosting ML code and pipelines | End-to-end MLOps automation | Storing datasets and models efficiently |
# | Typical ML Use Case | Commit training scripts | Host repository and publish models | Automate training pipelines | Manage model weights such as `.bin`, `.pt`, `.ckpt` |
# | Example Usage | `git commit`, `git push` | Create a repo, pull request workflow | CI/CD pipelines for training | Uploading a 10GB model without slowing repo |
# | Short Summary | Git manages versions | GitHub enables collaboration and social coding | GitLab enables full DevOps automation | Git LFS handles large binary files |
#
# ---
#
# # Short Summary (One Super-Clear Sentence)
#
# Git manages versions; GitHub and GitLab host Git repositories (GitHub for collaboration and social coding, GitLab for full DevOps automation); Git LFS extends Git to handle large binary files such as machine learning models.
